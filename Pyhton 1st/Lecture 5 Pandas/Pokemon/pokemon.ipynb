# %%
import os
import numpy as np
import pandas as pd
from IPython.display import Image
from matplotlib import pyplot as plt

# %%
# %matplotlib inline 
pd.options.mode.chained_assignment = None  # default='warn'

# %%
Image('https://images.vocus.cc/4ef2736d-b04f-4f66-86d8-331122a4eb1a.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# D:\Program Files\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# D:\Program Files\Anaconda3\lib\site-packages\IPython\core\display.py in _repr_mimebundle_(self, include, exclude)
#    1242         if self.embed:
#    1243             mimetype = self._mimetype
# -> 1244             data, metadata = self._data_and_metadata(always_both=True)
#    1245             if metadata:
#    1246                 metadata = {mimetype: metadata}
#
# D:\Program Files\Anaconda3\lib\site-packages\IPython\core\display.py in _data_and_metadata(self, always_both)
# ...

# %%
# prints current working directory full path
os.getcwd()
# Out:
# 'C:\\Users\\mockh\\Python Class 1 (Start)\\Pandas\\pokemon'

# %%
# reads csv file into 
poke = pd.read_csv('Pokemon_Data.csv')

# %%
poke.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
type(poke)
# Out:
# pandas.core.frame.DataFrame

# %%
type(poke['Name'])
# Out:
# pandas.core.series.Series

# %%
type(poke['Name'].values[0])
# Out:
# str

# %%
poke['Name'].head()
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
poke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
# #             800 non-null int64
# Name          800 non-null object
# Type 1        800 non-null object
# Type 2        414 non-null object
# HP            800 non-null int64
# Attack        800 non-null int64
# Defense       800 non-null int64
# Sp. Atk       800 non-null int64
# Sp. Def       800 non-null int64
# Speed         800 non-null int64
# Generation    800 non-null int64
# Legendary     800 non-null bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.6+ KB

# %%
poke.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
poke.isnull().sum()
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
poke['Legendary'].sum()
# Out:
# 65

# %%
poke.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
poke[poke.loc[:,'Name'].isin(['Pikachu', 'Bulbasaur', 'Charmander', 'Squirtle'])]
# Out:
#      #        Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1   Bulbasaur     Grass  Poison  45      49       49       65       65
# 4    4  Charmander      Fire     NaN  39      52       43       60       50
# 9    7    Squirtle     Water     NaN  44      48       65       50       64
# 30  25     Pikachu  Electric     NaN  35      55       40       50       50
#
#     Speed  Generation  Legendary
# 0      45           1      False
# 4      65           1      False
# 9      43           1      False
# 30     90           1      False

# %%
image_poke = poke[poke.loc[:,'Name'].isin(['Pikachu', 'Bulbasaur', 'Charmander', 'Squirtle'])]
image_poke
# Out:
#      #        Name    Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0    1   Bulbasaur     Grass  Poison  45      49       49       65       65
# 4    4  Charmander      Fire     NaN  39      52       43       60       50
# 9    7    Squirtle     Water     NaN  44      48       65       50       64
# 30  25     Pikachu  Electric     NaN  35      55       40       50       50
#
#     Speed  Generation  Legendary
# 0      45           1      False
# 4      65           1      False
# 9      43           1      False
# 30     90           1      False

# %%
image_poke.plot??

# %%
image_poke.plot.bar(x='Name', y='HP', color=['green', 'red', 'blue', 'yellow'], title='HP')

# %%
poke = poke.rename(columns={'#':'Number'})
poke.columns
# Out:
# Index(['Number', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
poke['Number'].groupby(poke['Number']).count().sort_values(ascending=False)
# Out:
# Number
# 479    6
# 386    4
# 711    4
# 710    4
# 150    3
# 6      3
# 413    3
# 646    3
# 303    2
# 302    2
# 648    2
# 65     2
# 555    2
# 487    2
# 308    2
# 254    2
# 306    2
# 310    2
# 492    2
# 214    2
# 384    2
# 383    2
# 382    2
# 647    2
# 641    2
# 645    2
# 94     2
# 115    2
# 445    2
# 257    2
#       ..
# 455    1
# 454    1
# 453    1
# 452    1
# 451    1
# 450    1
# 449    1
# 447    1
# 467    1
# 468    1
# 469    1
# 470    1
# 490    1
# 489    1
# 488    1
# 486    1
# 485    1
# 484    1
# 483    1
# 482    1
# 481    1
# 480    1
# 478    1
# 477    1
# 476    1
# 474    1
# 473    1
# 472    1
# 471    1
# 1      1
# Name: Number, Length: 721, dtype: int64

# %%
nodup_poke =poke.drop_duplicates('Number', keep='first', inplace=False)
nodup_poke.head()
# Out:
#    Number        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0       1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 1       2     Ivysaur  Grass  Poison  60      62       63       80       80
# 2       3    Venusaur  Grass  Poison  80      82       83      100      100
# 4       4  Charmander   Fire     NaN  39      52       43       60       50
# 5       5  Charmeleon   Fire     NaN  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 4     65           1      False
# 5     80           1      False

# %%
nodup_poke.reset_index(inplace=True, drop=True)
nodup_poke.head()
# Out:
#    Number        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0       1   Bulbasaur  Grass  Poison  45      49       49       65       65
# 1       2     Ivysaur  Grass  Poison  60      62       63       80       80
# 2       3    Venusaur  Grass  Poison  80      82       83      100      100
# 3       4  Charmander   Fire     NaN  39      52       43       60       50
# 4       5  Charmeleon   Fire     NaN  58      64       58       80       65
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# 3     65           1      False
# 4     80           1      False

# %%
poke['Number'].groupby(poke['Number']).count().sort_values(ascending=False)
# Out:
# Number
# 479    6
# 386    4
# 711    4
# 710    4
# 150    3
# 6      3
# 413    3
# 646    3
# 303    2
# 302    2
# 648    2
# 65     2
# 555    2
# 487    2
# 308    2
# 254    2
# 306    2
# 310    2
# 492    2
# 214    2
# 384    2
# 383    2
# 382    2
# 647    2
# 641    2
# 645    2
# 94     2
# 115    2
# 445    2
# 257    2
#       ..
# 455    1
# 454    1
# 453    1
# 452    1
# 451    1
# 450    1
# 449    1
# 447    1
# 467    1
# 468    1
# 469    1
# 470    1
# 490    1
# 489    1
# 488    1
# 486    1
# 485    1
# 484    1
# 483    1
# 482    1
# 481    1
# 480    1
# 478    1
# 477    1
# 476    1
# 474    1
# 473    1
# 472    1
# 471    1
# 1      1
# Name: Number, Length: 721, dtype: int64
